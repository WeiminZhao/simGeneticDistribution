# %%
import random
import matplotlib.pyplot as plt
import statistics

def initialize(malePopSize, femalePopSize, minDieOut, maxDieOut, alleleDistribution=0.5):
    maleP=[]
    femaleP=[]
    
    
    geneChoice=['a','A']
    #male generate
    for i in range(malePopSize):
        individual=[]
        g=random.choices(geneChoice,[alleleDistribution,1-alleleDistribution])[0]
        individual.append(g)
        #g=random.choice(geneChoice)##comment out if the initial is same allele
        individual.append(g) #append twice
        individual.append(random.randint(minDieOut,maxDieOut))# this will be the third index of each individual, and it is the life time of this individual
        
        maleP.append(individual)
    #female generate    
    for i in range(femalePopSize):
        individual=[]
        g=random.choices(geneChoice,[alleleDistribution,1-alleleDistribution])[0]
        individual.append(g)
        #g=random.choice(geneChoice)##comment out if the initial is same allele
        individual.append(g) #append twice
        individual.append(random.randint(minDieOut,maxDieOut))# this will be the third index of each individual, and it is the life time of this individual
        
        femaleP.append(individual)
    return maleP,femaleP

def crossover(malePop, femalePop, minDieOut, maxDieOut, crossoverTime=1000,):
    crossoverMale=random.choices(malePop,k=crossoverTime)
    crossoverFemale=random.choices(femalePop,k=crossoverTime)
    
    malenewGeneration=[]
    femalenewGeneration=[]
    
    for i in range(crossoverTime):
        newIndividual=[]
        
        #choice gene from male
        indexChoice=random.choice([0,1])
        newIndividual.append(crossoverMale[i][indexChoice])
        
        #choice gene from female
        indexChoice=random.choice([0,1])
        newIndividual.append(crossoverFemale[i][indexChoice])
        
        newIndividual.append(random.randint(minDieOut,maxDieOut))
        
        if(random.choice([0,1]) == 0):
            malenewGeneration.append(newIndividual)
        else:
            femalenewGeneration.append(newIndividual)
    return malenewGeneration,femalenewGeneration

def dieOut(malePop, femalePop):  
    i=0
    while i <len(malePop):
        malePop[i][2]-=1
        
        if malePop[i][2]<=0:  
            malePop.remove(malePop[i])
            continue
            
        i+=1
        
    i=0
    while i <len(femalePop):
        femalePop[i][2]-=1
        
        if femalePop[i][2]<=0:  
            femalePop.remove(femalePop[i])
            continue
            
        i+=1
    
    print("old population after die out: ",len(malePop)+len(femalePop))
    return malePop,femalePop



def checkDistribution(malePop, femalePop):
    aa=0
    Aa=0
    AA=0
    
    for individual in malePop:
        if individual[0]=='a' and individual[1]=='a':
            aa+=1
        elif individual[0]=='a' and individual[1]=='A':
            Aa+=1
        elif individual[0]=='A' and individual[1]=='a':   
            Aa+=1
        else:
            AA+=1
    for individual in femalePop:
        if individual[0]=='a' and individual[1]=='a':
            aa+=1
        elif individual[0]=='a' and individual[1]=='A':
            Aa+=1
        elif individual[0]=='A' and individual[1]=='a':   
            Aa+=1
        else:
            AA+=1
            
    return aa,Aa,AA



# malePopSize=10000
# femalePopSize=100

# minDieOut=5
# maxDieOut=10

# minCrRate=0.1
# maxCrRate=0.25

# iterationNumber=10

def simulationMain(alleleDistribution=0.5, malePopSize=10000, femalePopSize=100, minDieOut=5, maxDieOut=10, minCrRate=0.1, maxCrRate=0.25, iterationNumber=10, isPlot=True):
    print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
    print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
    print("The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):\n",alleleDistribution,malePopSize, femalePopSize, minDieOut, maxDieOut, minCrRate, maxCrRate, iterationNumber, isPlot)
    print("---------------------------------------------------------------------------------------------")
    malePop=[]
    femalePop=[]
    
    aaRecord=[]
    AaRecord=[]
    AARecord=[]

    malePop,femalePop=initialize(malePopSize,femalePopSize,minDieOut,maxDieOut ,alleleDistribution)

    aa,Aa,AA=checkDistribution(malePop, femalePop)
    aaRecord.append(aa)
    AaRecord.append(Aa)
    AARecord.append(AA)

    print("This is start genetic distribution:",aa,Aa,AA)
    print("This is start population distribution (male/female):",len(malePop),len(femalePop))

    for iteration in range(iterationNumber):
        print("This is iteration",iteration)
        print("start population for this round: ",len(malePop)+len(femalePop))


        currTotal=len(malePop)+len(femalePop)
        newMalePop,newFemalePop=crossover(malePop,femalePop,minDieOut,maxDieOut,random.randint(int(currTotal*minCrRate),int(currTotal*maxCrRate))) #we want the crossover rate between a percent of total populations

        malePop,femalePop=dieOut(malePop,femalePop)

        malePop.extend(newMalePop)
        femalePop.extend(newFemalePop)
    #     malePop=newMalePop
    #     femalePop=newFemalePop
        print("end population for this round: ",len(malePop)+len(femalePop))

        aa,Aa,AA=checkDistribution(malePop, femalePop)
        aaRecord.append(aa)
        AaRecord.append(Aa)
        AARecord.append(AA)
        print("Distribution for current iteration:",aa,Aa,AA)
        print("Population for current iteration (male/female):",len(malePop),len(femalePop))
        print("'============'================'=============='============='============='")

    aa,Aa,AA=checkDistribution(malePop, femalePop)

    print("Final Distribution after",iterationNumber,"iterations: ",aa,Aa,AA)
    print("Final Frequency after",iterationNumber,"iterations: ",aa/(aa+Aa+AA),Aa/(aa+Aa+AA),AA/(aa+Aa+AA))
    print("Final Distribution for a and A: ",2*aa+Aa,Aa+2*AA)
    print("Final Frequency for a and A: ",(2*aa+Aa)/((aa+Aa+AA)*2),(Aa+2*AA)/((aa+Aa+AA)*2))
    print("Final male and female population: ",len(malePop),len(femalePop))
    
    if isPlot:
        plt.figure(1)
        plt.bar(['aa','Aa','AA'],[aa,Aa,AA])
        plt.figure(2)
        plt.plot(aaRecord)
        plt.plot(AaRecord)
        plt.plot(AARecord)
        plt.show()
    
    return aa, Aa, AA
    #print("verification for random pick: ", random.choices([0,1,2],k=9))#to verify if there is a replacement

# %%
aaRecordF=[]
AaRecordF=[]
AARecordF=[]
freqForaRecord=[]
for repeat in range(100):
    print("############################################################################")
    print("THIS IS REPEAT:", repeat)
    dO=random.randint(1,1)
    dO2=random.randint(1,1)
    if dO>dO2:
        temp=dO2
        dO2=dO
        dO=temp
    crR=random.uniform(1,1)
    crR2=random.uniform(1,1)
    if crR>crR2:
        temp=crR2
        crR2=crR
        crR=temp
    
    faa,fAa,fAA=simulationMain(alleleDistribution=random.uniform(0,1),malePopSize=random.randint(100,10000), femalePopSize=random.randint(100,10000), minDieOut=dO, maxDieOut=dO2, minCrRate=crR, maxCrRate=crR2, iterationNumber=10, isPlot=False)
    
    aaRecordF.append(faa/(faa+fAa+fAA))
    AaRecordF.append(fAa/(faa+fAa+fAA))
    AARecordF.append(fAA/(faa+fAa+fAA))
    freqForaRecord.append((2*faa+fAa)/((faa+fAa+fAA)*2))
    

plt.figure(10)

plt.plot(freqForaRecord,aaRecordF, 'o')
plt.plot(freqForaRecord,AaRecordF, 'o')
plt.plot(freqForaRecord,AARecordF, 'o')
# plt.plot(aaRecordT)
# plt.plot(AaRecordT)
# plt.plot(AARecordT)

plt.show()
# Out:
# ############################################################################
# THIS IS REPEAT: 0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.09640631218837525 2520 787 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 321 0 2986
# This is start population distribution (male/female): 2520 787
# This is iteration 0
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 32 600 2675
# Population for current iteration (male/female): 1603 1704
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 29 587 2691
# Population for current iteration (male/female): 1678 1629
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 28 596 2683
# Population for current iteration (male/female): 1704 1603
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 27 617 2663
# Population for current iteration (male/female): 1619 1688
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 32 595 2680
# Population for current iteration (male/female): 1625 1682
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 38 568 2701
# Population for current iteration (male/female): 1705 1602
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 35 578 2694
# Population for current iteration (male/female): 1661 1646
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 37 567 2703
# Population for current iteration (male/female): 1670 1637
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 32 546 2729
# Population for current iteration (male/female): 1686 1621
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  3307
# old population after die out:  0
# end population for this round:  3307
# Distribution for current iteration: 34 559 2714
# Population for current iteration (male/female): 1604 1703
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  34 559 2714
# Final Frequency after 10 iterations:  0.010281221651043242 0.16903537949803446 0.8206833988509223
# Final Distribution for a and A:  627 5987
# Final Frequency for a and A:  0.09479891140006048 0.9052010885999395
# Final male and female population:  1604 1703
# ############################################################################
# THIS IS REPEAT: 1
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.8935291075157823 4683 7177 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 10541 0 1319
# This is start population distribution (male/female): 4683 7177
# This is iteration 0
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9324 2376 160
# Population for current iteration (male/female): 5983 5877
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9294 2419 147
# Population for current iteration (male/female): 6001 5859
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9305 2421 134
# Population for current iteration (male/female): 5927 5933
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9353 2362 145
# Population for current iteration (male/female): 5982 5878
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9386 2321 153
# Population for current iteration (male/female): 5933 5927
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9320 2385 155
# Population for current iteration (male/female): 5967 5893
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9342 2367 151
# Population for current iteration (male/female): 5984 5876
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9335 2379 146
# Population for current iteration (male/female): 5914 5946
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9317 2394 149
# Population for current iteration (male/female): 5893 5967
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  11860
# old population after die out:  0
# end population for this round:  11860
# Distribution for current iteration: 9374 2340 146
# Population for current iteration (male/female): 5926 5934
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  9374 2340 146
# Final Frequency after 10 iterations:  0.7903878583473861 0.1973018549747049 0.012310286677908937
# Final Distribution for a and A:  21088 2632
# Final Frequency for a and A:  0.8890387858347386 0.11096121416526138
# Final male and female population:  5926 5934
# ############################################################################
# THIS IS REPEAT: 2
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.10360061478452565 6004 4197 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 1061 0 9140
# This is start population distribution (male/female): 6004 4197
# This is iteration 0
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 115 1909 8177
# Population for current iteration (male/female): 5161 5040
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 96 1920 8185
# Population for current iteration (male/female): 5108 5093
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 110 1862 8229
# Population for current iteration (male/female): 5061 5140
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 100 1856 8245
# Population for current iteration (male/female): 5028 5173
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 103 1882 8216
# Population for current iteration (male/female): 5056 5145
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 89 1816 8296
# Population for current iteration (male/female): 5089 5112
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 100 1815 8286
# Population for current iteration (male/female): 5154 5047
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 99 1873 8229
# Population for current iteration (male/female): 5112 5089
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 84 1878 8239
# Population for current iteration (male/female): 5157 5044
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  10201
# old population after die out:  0
# end population for this round:  10201
# Distribution for current iteration: 106 1856 8239
# Population for current iteration (male/female): 5139 5062
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  106 1856 8239
# Final Frequency after 10 iterations:  0.010391138123713362 0.1819429467699245 0.8076659151063621
# Final Distribution for a and A:  2068 18334
# Final Frequency for a and A:  0.10136261150867562 0.8986373884913244
# Final male and female population:  5139 5062
# ############################################################################
# THIS IS REPEAT: 3
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.9869722316649215 6710 9387 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 15883 0 214
# This is start population distribution (male/female): 6710 9387
# This is iteration 0
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15634 461 2
# Population for current iteration (male/female): 8023 8074
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15626 469 2
# Population for current iteration (male/female): 8025 8072
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15623 472 2
# Population for current iteration (male/female): 8023 8074
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15611 485 1
# Population for current iteration (male/female): 8029 8068
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15630 464 3
# Population for current iteration (male/female): 8018 8079
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15599 495 3
# Population for current iteration (male/female): 7986 8111
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15583 510 4
# Population for current iteration (male/female): 8119 7978
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15557 535 5
# Population for current iteration (male/female): 8065 8032
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15540 551 6
# Population for current iteration (male/female): 7976 8121
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  16097
# old population after die out:  0
# end population for this round:  16097
# Distribution for current iteration: 15556 539 2
# Population for current iteration (male/female): 8016 8081
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  15556 539 2
# Final Frequency after 10 iterations:  0.9663912530285146 0.03348450021743182 0.00012424675405355034
# Final Distribution for a and A:  31651 543
# Final Frequency for a and A:  0.9831335031372306 0.01686649686276946
# Final male and female population:  8016 8081
# ############################################################################
# THIS IS REPEAT: 4
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.7134973242557532 6435 8490 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 10602 0 4323
# This is start population distribution (male/female): 6435 8490
# This is iteration 0
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7620 6050 1255
# Population for current iteration (male/female): 7377 7548
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7555 6106 1264
# Population for current iteration (male/female): 7378 7547
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7514 6189 1222
# Population for current iteration (male/female): 7476 7449
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7552 6146 1227
# Population for current iteration (male/female): 7366 7559
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7635 6063 1227
# Population for current iteration (male/female): 7487 7438
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7626 6110 1189
# Population for current iteration (male/female): 7483 7442
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7625 6090 1210
# Population for current iteration (male/female): 7341 7584
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7588 6090 1247
# Population for current iteration (male/female): 7514 7411
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7498 6225 1202
# Population for current iteration (male/female): 7387 7538
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  14925
# old population after die out:  0
# end population for this round:  14925
# Distribution for current iteration: 7541 6166 1218
# Population for current iteration (male/female): 7521 7404
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  7541 6166 1218
# Final Frequency after 10 iterations:  0.5052596314907872 0.41313232830820773 0.08160804020100502
# Final Distribution for a and A:  21248 8602
# Final Frequency for a and A:  0.7118257956448911 0.2881742043551089
# Final male and female population:  7521 7404
# ############################################################################
# THIS IS REPEAT: 5
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.38727508177571013 7710 8754 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 6391 0 10073
# This is start population distribution (male/female): 7710 8754
# This is iteration 0
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2465 7876 6123
# Population for current iteration (male/female): 8023 8441
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2503 7897 6064
# Population for current iteration (male/female): 8188 8276
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2515 7851 6098
# Population for current iteration (male/female): 8196 8268
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2493 7870 6101
# Population for current iteration (male/female): 8155 8309
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2496 7910 6058
# Population for current iteration (male/female): 8296 8168
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2518 7910 6036
# Population for current iteration (male/female): 8124 8340
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2556 7730 6178
# Population for current iteration (male/female): 8281 8183
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2523 7780 6161
# Population for current iteration (male/female): 8375 8089
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2508 7857 6099
# Population for current iteration (male/female): 8328 8136
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  16464
# old population after die out:  0
# end population for this round:  16464
# Distribution for current iteration: 2531 7759 6174
# Population for current iteration (male/female): 8253 8211
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  2531 7759 6174
# Final Frequency after 10 iterations:  0.1537293488824101 0.47127065111758987 0.375
# Final Distribution for a and A:  12821 20107
# Final Frequency for a and A:  0.38936467444120504 0.610635325558795
# Final male and female population:  8253 8211
# ############################################################################
# THIS IS REPEAT: 6
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.7294522471256447 9035 4523 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 9808 0 3750
# This is start population distribution (male/female): 9035 4523
# This is iteration 0
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 7141 5405 1012
# Population for current iteration (male/female): 6672 6886
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 7066 5457 1035
# Population for current iteration (male/female): 6768 6790
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 7020 5537 1001
# Population for current iteration (male/female): 6849 6709
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 7030 5498 1030
# Population for current iteration (male/female): 6804 6754
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 7094 5366 1098
# Population for current iteration (male/female): 6606 6952
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 7013 5507 1038
# Population for current iteration (male/female): 6751 6807
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 7030 5503 1025
# Population for current iteration (male/female): 6701 6857
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 7069 5388 1101
# Population for current iteration (male/female): 6899 6659
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 7004 5461 1093
# Population for current iteration (male/female): 6870 6688
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  13558
# old population after die out:  0
# end population for this round:  13558
# Distribution for current iteration: 6980 5476 1102
# Population for current iteration (male/female): 6785 6773
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  6980 5476 1102
# Final Frequency after 10 iterations:  0.514825195456557 0.40389437970202097 0.08128042484142203
# Final Distribution for a and A:  19436 7680
# Final Frequency for a and A:  0.7167723853075675 0.2832276146924325
# Final male and female population:  6785 6773
# ############################################################################
# THIS IS REPEAT: 7
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.5405774895716506 9011 177 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 5036 0 4152
# This is start population distribution (male/female): 9011 177
# This is iteration 0
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2511 4636 2041
# Population for current iteration (male/female): 4613 4575
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2545 4603 2040
# Population for current iteration (male/female): 4568 4620
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2504 4628 2056
# Population for current iteration (male/female): 4596 4592
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2587 4444 2157
# Population for current iteration (male/female): 4580 4608
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2490 4556 2142
# Population for current iteration (male/female): 4522 4666
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2486 4563 2139
# Population for current iteration (male/female): 4588 4600
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2441 4593 2154
# Population for current iteration (male/female): 4598 4590
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2464 4543 2181
# Population for current iteration (male/female): 4628 4560
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2452 4520 2216
# Population for current iteration (male/female): 4571 4617
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  9188
# old population after die out:  0
# end population for this round:  9188
# Distribution for current iteration: 2485 4494 2209
# Population for current iteration (male/female): 4567 4621
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  2485 4494 2209
# Final Frequency after 10 iterations:  0.2704614714845451 0.4891162385720505 0.24042228994340445
# Final Distribution for a and A:  9464 8912
# Final Frequency for a and A:  0.5150195907705704 0.4849804092294297
# Final male and female population:  4567 4621
# ############################################################################
# THIS IS REPEAT: 8
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.7664981231191947 6780 5912 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 9664 0 3028
# This is start population distribution (male/female): 6780 5912
# This is iteration 0
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7344 4623 725
# Population for current iteration (male/female): 6401 6291
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7457 4540 695
# Population for current iteration (male/female): 6377 6315
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7392 4580 720
# Population for current iteration (male/female): 6367 6325
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7464 4571 657
# Population for current iteration (male/female): 6350 6342
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7486 4490 716
# Population for current iteration (male/female): 6343 6349
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7511 4494 687
# Population for current iteration (male/female): 6395 6297
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7555 4479 658
# Population for current iteration (male/female): 6395 6297
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7592 4470 630
# Population for current iteration (male/female): 6282 6410
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7781 4273 638
# Population for current iteration (male/female): 6377 6315
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  12692
# old population after die out:  0
# end population for this round:  12692
# Distribution for current iteration: 7751 4304 637
# Population for current iteration (male/female): 6338 6354
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  7751 4304 637
# Final Frequency after 10 iterations:  0.610699653324929 0.3391112511818468 0.050189095493224076
# Final Distribution for a and A:  19806 5578
# Final Frequency for a and A:  0.7802552789158526 0.2197447210841475
# Final male and female population:  6338 6354
# ############################################################################
# THIS IS REPEAT: 9
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.6172546118608885 6880 5679 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 7730 0 4829
# This is start population distribution (male/female): 6880 5679
# This is iteration 0
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4701 5993 1865
# Population for current iteration (male/female): 6161 6398
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4750 5844 1965
# Population for current iteration (male/female): 6360 6199
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4684 6019 1856
# Population for current iteration (male/female): 6258 6301
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4704 5979 1876
# Population for current iteration (male/female): 6156 6403
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4681 5958 1920
# Population for current iteration (male/female): 6196 6363
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4736 5935 1888
# Population for current iteration (male/female): 6161 6398
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4770 5924 1865
# Population for current iteration (male/female): 6292 6267
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4722 6002 1835
# Population for current iteration (male/female): 6345 6214
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4837 5877 1845
# Population for current iteration (male/female): 6190 6369
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  12559
# old population after die out:  0
# end population for this round:  12559
# Distribution for current iteration: 4826 5920 1813
# Population for current iteration (male/female): 6253 6306
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  4826 5920 1813
# Final Frequency after 10 iterations:  0.3842662632375189 0.47137510948323913 0.14435862727924198
# Final Distribution for a and A:  15572 9546
# Final Frequency for a and A:  0.6199538179791385 0.38004618202086154
# Final male and female population:  6253 6306
# ############################################################################
# THIS IS REPEAT: 10
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.6374888361242118 5634 2859 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 5461 0 3032
# This is start population distribution (male/female): 5634 2859
# This is iteration 0
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3496 3858 1139
# Population for current iteration (male/female): 4128 4365
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3522 3859 1112
# Population for current iteration (male/female): 4243 4250
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3518 3894 1081
# Population for current iteration (male/female): 4219 4274
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3485 3927 1081
# Population for current iteration (male/female): 4213 4280
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3535 3829 1129
# Population for current iteration (male/female): 4285 4208
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3399 3995 1099
# Population for current iteration (male/female): 4272 4221
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3454 3905 1134
# Population for current iteration (male/female): 4207 4286
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3374 3992 1127
# Population for current iteration (male/female): 4322 4171
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3367 3995 1131
# Population for current iteration (male/female): 4268 4225
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  8493
# old population after die out:  0
# end population for this round:  8493
# Distribution for current iteration: 3408 3951 1134
# Population for current iteration (male/female): 4267 4226
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  3408 3951 1134
# Final Frequency after 10 iterations:  0.4012716354645002 0.4652066407629813 0.13352172377251856
# Final Distribution for a and A:  10767 6219
# Final Frequency for a and A:  0.6338749558459909 0.3661250441540092
# Final male and female population:  4267 4226
# ############################################################################
# THIS IS REPEAT: 11
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.8456550169360478 6540 9811 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 13859 0 2492
# This is start population distribution (male/female): 6540 9811
# This is iteration 0
# start population for this round:  16351
# old population after die out:  0
# end population for this round:  16351
# Distribution for current iteration: 11811 4163 377
# Population for current iteration (male/female): 8181 8170
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  16351
# old population after die out:  0
# end population for this round:  16351
# Distribution for current iteration: 11655 4321 375
# Population for current iteration (male/female): 8148 8203
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  16351
# old population after die out:  0
# end population for this round:  16351
# Distribution for current iteration: 11608 4349 394
# Population for current iteration (male/female): 8148 8203
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  16351
# old population after die out:  0
# end population for this round:  16351
# Distribution for current iteration: 11702 4232 417
# Population for current iteration (male/female): 8172 8179
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  16351
# old population after die out:  0
# end population for this round:  16351
# Distribution for current iteration: 11631 4321 399
# Population for current iteration (male/female): 8101 8250
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  16351
# old population after die out:  0
# end population for this round:  16351
# Distribution for current iteration: 11669 4298 384
# ...
# This is start genetic distribution: 1415 0 6465
# This is start population distribution (male/female): 5115 2765
# This is iteration 0
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 235 2328 5317
# Population for current iteration (male/female): 3975 3905
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 233 2367 5280
# Population for current iteration (male/female): 3947 3933
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 225 2299 5356
# Population for current iteration (male/female): 3932 3948
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 254 2303 5323
# Population for current iteration (male/female): 3945 3935
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 269 2288 5323
# Population for current iteration (male/female): 3946 3934
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 266 2302 5312
# Population for current iteration (male/female): 4020 3860
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 248 2359 5273
# Population for current iteration (male/female): 3911 3969
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 278 2312 5290
# Population for current iteration (male/female): 3863 4017
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 251 2346 5283
# Population for current iteration (male/female): 3917 3963
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  7880
# old population after die out:  0
# end population for this round:  7880
# Distribution for current iteration: 249 2338 5293
# Population for current iteration (male/female): 3924 3956
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  249 2338 5293
# Final Frequency after 10 iterations:  0.03159898477157361 0.2967005076142132 0.6717005076142132
# Final Distribution for a and A:  2836 12924
# Final Frequency for a and A:  0.1799492385786802 0.8200507614213198
# Final male and female population:  3924 3956
# ############################################################################
# THIS IS REPEAT: 97
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.7457754440712795 6424 4293 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 8013 0 2704
# This is start population distribution (male/female): 6424 4293
# This is iteration 0
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6036 4015 666
# Population for current iteration (male/female): 5357 5360
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6029 4013 675
# Population for current iteration (male/female): 5408 5309
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6070 4006 641
# Population for current iteration (male/female): 5378 5339
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6179 3869 669
# Population for current iteration (male/female): 5348 5369
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6100 3986 631
# Population for current iteration (male/female): 5373 5344
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6170 3899 648
# Population for current iteration (male/female): 5345 5372
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6238 3888 591
# Population for current iteration (male/female): 5337 5380
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6278 3827 612
# Population for current iteration (male/female): 5329 5388
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6171 3944 602
# Population for current iteration (male/female): 5320 5397
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  10717
# old population after die out:  0
# end population for this round:  10717
# Distribution for current iteration: 6216 3887 614
# Population for current iteration (male/female): 5429 5288
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  6216 3887 614
# Final Frequency after 10 iterations:  0.5800130633572829 0.3626947839880564 0.05729215265466082
# Final Distribution for a and A:  16319 5115
# Final Frequency for a and A:  0.761360455351311 0.238639544648689
# Final male and female population:  5429 5288
# ############################################################################
# THIS IS REPEAT: 98
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.39016677633187524 5255 6260 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 4427 0 7088
# This is start population distribution (male/female): 5255 6260
# This is iteration 0
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1698 5451 4366
# Population for current iteration (male/female): 5726 5789
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1680 5422 4413
# Population for current iteration (male/female): 5753 5762
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1702 5377 4436
# Population for current iteration (male/female): 5700 5815
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1661 5394 4460
# Population for current iteration (male/female): 5582 5933
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1640 5478 4397
# Population for current iteration (male/female): 5674 5841
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1693 5381 4441
# Population for current iteration (male/female): 5778 5737
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1585 5542 4388
# Population for current iteration (male/female): 5746 5769
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1616 5363 4536
# Population for current iteration (male/female): 5754 5761
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1547 5463 4505
# Population for current iteration (male/female): 5820 5695
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  11515
# old population after die out:  0
# end population for this round:  11515
# Distribution for current iteration: 1590 5491 4434
# Population for current iteration (male/female): 5828 5687
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  1590 5491 4434
# Final Frequency after 10 iterations:  0.13808076422058185 0.4768562744246635 0.38506296135475465
# Final Distribution for a and A:  8671 14359
# Final Frequency for a and A:  0.3765089014329136 0.6234910985670864
# Final male and female population:  5828 5687
# ############################################################################
# THIS IS REPEAT: 99
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.5928890125540354 458 7111 1 1 1.0 1.0 10 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 4538 0 3031
# This is start population distribution (male/female): 458 7111
# This is iteration 0
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2712 3614 1243
# Population for current iteration (male/female): 3781 3788
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2720 3594 1255
# Population for current iteration (male/female): 3765 3804
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2655 3673 1241
# Population for current iteration (male/female): 3776 3793
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2671 3666 1232
# Population for current iteration (male/female): 3747 3822
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2636 3662 1271
# Population for current iteration (male/female): 3793 3776
# '============'================'=============='============='============='
# This is iteration 5
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2669 3567 1333
# Population for current iteration (male/female): 3746 3823
# '============'================'=============='============='============='
# This is iteration 6
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2657 3635 1277
# Population for current iteration (male/female): 3785 3784
# '============'================'=============='============='============='
# This is iteration 7
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2742 3571 1256
# Population for current iteration (male/female): 3763 3806
# '============'================'=============='============='============='
# This is iteration 8
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2605 3712 1252
# Population for current iteration (male/female): 3804 3765
# '============'================'=============='============='============='
# This is iteration 9
# start population for this round:  7569
# old population after die out:  0
# end population for this round:  7569
# Distribution for current iteration: 2604 3669 1296
# Population for current iteration (male/female): 3802 3767
# '============'================'=============='============='============='
# Final Distribution after 10 iterations:  2604 3669 1296
# Final Frequency after 10 iterations:  0.34403487911216807 0.48474038842647643 0.17122473246135553
# Final Distribution for a and A:  8877 6261
# Final Frequency for a and A:  0.5864050733254063 0.41359492667459374
# Final male and female population:  3802 3767
