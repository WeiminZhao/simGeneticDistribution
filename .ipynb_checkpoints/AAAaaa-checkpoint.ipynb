# %%
import random
import matplotlib.pyplot as plt
import statistics

def initialize(malePopSize, femalePopSize, minDieOut, maxDieOut, alleleDistribution=0.5):
    maleP=[]
    femaleP=[]
    
    
    geneChoice=['a','A']
    #male generate
    for i in range(malePopSize):
        individual=[]
        g=random.choices(geneChoice,[alleleDistribution,1-alleleDistribution])[0]
        individual.append(g)
        #g=random.choice(geneChoice)##comment out if the initial is same allele
        individual.append(g) #append twice
        individual.append(random.randint(minDieOut,maxDieOut))# this will be the third index of each individual, and it is the life time of this individual
        
        maleP.append(individual)
    #female generate    
    for i in range(femalePopSize):
        individual=[]
        g=random.choices(geneChoice,[alleleDistribution,1-alleleDistribution])[0]
        individual.append(g)
        #g=random.choice(geneChoice)##comment out if the initial is same allele
        individual.append(g) #append twice
        individual.append(random.randint(minDieOut,maxDieOut))# this will be the third index of each individual, and it is the life time of this individual
        
        femaleP.append(individual)
    return maleP,femaleP

def crossover(malePop, femalePop, minDieOut, maxDieOut, crossoverTime=1000,):
    crossoverMale=random.choices(malePop,k=crossoverTime)
    crossoverFemale=random.choices(femalePop,k=crossoverTime)
    
    malenewGeneration=[]
    femalenewGeneration=[]
    
    for i in range(crossoverTime):
        newIndividual=[]
        
        #choice gene from male
        indexChoice=random.choice([0,1])
        newIndividual.append(crossoverMale[i][indexChoice])
        
        #choice gene from female
        indexChoice=random.choice([0,1])
        newIndividual.append(crossoverFemale[i][indexChoice])
        
        newIndividual.append(random.randint(minDieOut,maxDieOut))
        
        if(random.choice([0,1]) == 0):
            malenewGeneration.append(newIndividual)
        else:
            femalenewGeneration.append(newIndividual)
    return malenewGeneration,femalenewGeneration

def dieOut(malePop, femalePop):  
    i=0
    while i <len(malePop):
        malePop[i][2]-=1
        
        if malePop[i][2]<=0:  
            malePop.remove(malePop[i])
            continue
            
        i+=1
        
    i=0
    while i <len(femalePop):
        femalePop[i][2]-=1
        
        if femalePop[i][2]<=0:  
            femalePop.remove(femalePop[i])
            continue
            
        i+=1
    
    print("old population after die out: ",len(malePop)+len(femalePop))
    return malePop,femalePop



def checkDistribution(malePop, femalePop):
    aa=0
    Aa=0
    AA=0
    
    for individual in malePop:
        if individual[0]=='a' and individual[1]=='a':
            aa+=1
        elif individual[0]=='a' and individual[1]=='A':
            Aa+=1
        elif individual[0]=='A' and individual[1]=='a':   
            Aa+=1
        else:
            AA+=1
    for individual in femalePop:
        if individual[0]=='a' and individual[1]=='a':
            aa+=1
        elif individual[0]=='a' and individual[1]=='A':
            Aa+=1
        elif individual[0]=='A' and individual[1]=='a':   
            Aa+=1
        else:
            AA+=1
            
    return aa,Aa,AA



# malePopSize=10000
# femalePopSize=100

# minDieOut=5
# maxDieOut=10

# minCrRate=0.1
# maxCrRate=0.25

# iterationNumber=10

def simulationMain(alleleDistribution=0.5, malePopSize=10000, femalePopSize=100, minDieOut=5, maxDieOut=10, minCrRate=0.1, maxCrRate=0.25, iterationNumber=10, isPlot=True):
    print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
    print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
    print("The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):\n",alleleDistribution,malePopSize, femalePopSize, minDieOut, maxDieOut, minCrRate, maxCrRate, iterationNumber, isPlot)
    print("---------------------------------------------------------------------------------------------")
    malePop=[]
    femalePop=[]
    
    aaRecord=[]
    AaRecord=[]
    AARecord=[]

    malePop,femalePop=initialize(malePopSize,femalePopSize,minDieOut,maxDieOut ,alleleDistribution)

    aa,Aa,AA=checkDistribution(malePop, femalePop)
    aaRecord.append(aa)
    AaRecord.append(Aa)
    AARecord.append(AA)

    print("This is start genetic distribution:",aa,Aa,AA)
    print("This is start population distribution (male/female):",len(malePop),len(femalePop))

    for iteration in range(iterationNumber):
        print("This is iteration",iteration)
        print("start population for this round: ",len(malePop)+len(femalePop))


        currTotal=len(malePop)+len(femalePop)
        newMalePop,newFemalePop=crossover(malePop,femalePop,minDieOut,maxDieOut,random.randint(int(currTotal*minCrRate),int(currTotal*maxCrRate))) #we want the crossover rate between a percent of total populations

        malePop,femalePop=dieOut(malePop,femalePop)

        malePop.extend(newMalePop)
        femalePop.extend(newFemalePop)
    #     malePop=newMalePop
    #     femalePop=newFemalePop
        print("end population for this round: ",len(malePop)+len(femalePop))

        aa,Aa,AA=checkDistribution(malePop, femalePop)
        aaRecord.append(aa)
        AaRecord.append(Aa)
        AARecord.append(AA)
        print("Distribution for current iteration:",aa,Aa,AA)
        print("Population for current iteration (male/female):",len(malePop),len(femalePop))
        print("'============'================'=============='============='============='")

    aa,Aa,AA=checkDistribution(malePop, femalePop)

    print("Final Distribution after",iterationNumber,"iterations: ",aa,Aa,AA)
    print("Final Frequency after",iterationNumber,"iterations: ",aa/(aa+Aa+AA),Aa/(aa+Aa+AA),AA/(aa+Aa+AA))
    print("Final Distribution for a and A: ",2*aa+Aa,Aa+2*AA)
    print("Final Frequency for a and A: ",(2*aa+Aa)/((aa+Aa+AA)*2),(Aa+2*AA)/((aa+Aa+AA)*2))
    print("Final male and female population: ",len(malePop),len(femalePop))
    
    if isPlot:
        plt.figure(1)
        plt.bar(['aa','Aa','AA'],[aa,Aa,AA])
        plt.figure(2)
        plt.plot(aaRecord)
        plt.plot(AaRecord)
        plt.plot(AARecord)
        plt.show()
    
    return aa, Aa, AA
    #print("verification for random pick: ", random.choices([0,1,2],k=9))#to verify if there is a replacement

# %%
aaRecordF=[]
AaRecordF=[]
AARecordF=[]
freqForaRecord=[]
for repeat in range(50):
    print("############################################################################")
    print("THIS IS REPEAT:", repeat)
    dO=random.randint(1,5)
    dO2=random.randint(1,5)
    if dO>dO2:
        temp=dO2
        dO2=dO
        dO=temp
    crR=random.uniform(0.1,1)
    crR2=random.uniform(0.1,1)
    if crR>crR2:
        temp=crR2
        crR2=crR
        crR=temp
    
    faa,fAa,fAA=simulationMain(alleleDistribution=random.uniform(0,1),malePopSize=random.randint(100,10000), femalePopSize=random.randint(100,10000), minDieOut=dO, maxDieOut=dO2, minCrRate=crR, maxCrRate=crR2, iterationNumber=5, isPlot=False)
    
    #will record the frequency of the pairs here
    aaRecordF.append(faa/(faa+fAa+fAA))
    AaRecordF.append(fAa/(faa+fAa+fAA))
    AARecordF.append(fAA/(faa+fAa+fAA))
    #record the frequency of the single allele here
    freqForaRecord.append((2*faa+fAa)/((faa+fAa+fAA)*2))
    

plt.figure(10)

plt.plot(freqForaRecord,aaRecordF, 'o')
plt.plot(freqForaRecord,AaRecordF, 'o')
plt.plot(freqForaRecord,AARecordF, 'o')
# plt.plot(aaRecordT)
# plt.plot(AaRecordT)
# plt.plot(AARecordT)

plt.show()
# Out:
# ############################################################################
# THIS IS REPEAT: 0
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.6441099022137771 4310 5738 1 5 0.319821768489837 0.9332249470271254 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 6506 0 3542
# This is start population distribution (male/female): 4310 5738
# This is iteration 0
# start population for this round:  10048
# old population after die out:  8086
# end population for this round:  16785
# Distribution for current iteration: 8963 3895 3927
# Population for current iteration (male/female): 7788 8997
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  16785
# old population after die out:  13068
# end population for this round:  21058
# Distribution for current iteration: 10288 6861 3909
# Population for current iteration (male/female): 10117 10941
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  21058
# old population after die out:  15717
# end population for this round:  22736
# Distribution for current iteration: 10472 8596 3668
# Population for current iteration (male/female): 11062 11674
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  22736
# old population after die out:  15947
# end population for this round:  30685
# Distribution for current iteration: 13377 13054 4254
# Population for current iteration (male/female): 15156 15529
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  30685
# old population after die out:  21059
# end population for this round:  48805
# Distribution for current iteration: 20602 22209 5994
# Population for current iteration (male/female): 24402 24403
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  20602 22209 5994
# Final Frequency after 5 iterations:  0.4221288802376806 0.4550558344431923 0.12281528531912714
# Final Distribution for a and A:  63413 34197
# Final Frequency for a and A:  0.6496567974592767 0.35034320254072326
# Final male and female population:  24402 24403
# ############################################################################
# THIS IS REPEAT: 1
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.828725872821721 8126 2354 2 4 0.6701580251344148 0.8749764748914772 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 8654 0 1826
# This is start population distribution (male/female): 8126 2354
# This is iteration 0
# start population for this round:  10480
# old population after die out:  10480
# end population for this round:  18045
# Distribution for current iteration: 13988 2021 2036
# Population for current iteration (male/female): 11927 6118
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  18045
# old population after die out:  14670
# end population for this round:  30030
# Distribution for current iteration: 21883 6265 1882
# Population for current iteration (male/female): 16925 13105
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  30030
# old population after die out:  23938
# end population for this round:  49488
# Distribution for current iteration: 34872 12712 1904
# Population for current iteration (male/female): 25547 23941
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  49488
# old population after die out:  38345
# end population for this round:  77058
# Distribution for current iteration: 53564 21367 2127
# Population for current iteration (male/female): 38473 38585
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  77058
# old population after die out:  60894
# end population for this round:  127907
# Distribution for current iteration: 88720 35615 3572
# Population for current iteration (male/female): 63785 64122
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  88720 35615 3572
# Final Frequency after 5 iterations:  0.6936289647947337 0.27844449482827366 0.02792654037699266
# Final Distribution for a and A:  213055 42759
# Final Frequency for a and A:  0.8328512122088705 0.1671487877911295
# Final male and female population:  63785 64122
# ############################################################################
# THIS IS REPEAT: 2
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.019428326690046016 8615 5443 1 2 0.11840506267243023 0.756741186024847 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 287 0 13771
# This is start population distribution (male/female): 8615 5443
# This is iteration 0
# start population for this round:  14058
# old population after die out:  6917
# end population for this round:  16803
# Distribution for current iteration: 161 396 16246
# Population for current iteration (male/female): 9221 7582
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  16803
# old population after die out:  4941
# end population for this round:  14069
# Distribution for current iteration: 8 585 13476
# Population for current iteration (male/female): 7086 6983
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  14069
# old population after die out:  4591
# end population for this round:  14512
# Distribution for current iteration: 10 594 13908
# Population for current iteration (male/female): 7244 7268
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  14512
# old population after die out:  4899
# end population for this round:  14458
# Distribution for current iteration: 14 641 13803
# Population for current iteration (male/female): 7167 7291
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  14458
# old population after die out:  4870
# end population for this round:  13983
# Distribution for current iteration: 9 648 13326
# Population for current iteration (male/female): 6981 7002
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  9 648 13326
# Final Frequency after 5 iterations:  0.0006436387041407423 0.04634198669813345 0.9530143745977258
# Final Distribution for a and A:  666 27300
# Final Frequency for a and A:  0.023814632053207465 0.9761853679467926
# Final male and female population:  6981 7002
# ############################################################################
# THIS IS REPEAT: 3
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.7419803084064645 7649 4527 2 2 0.7790457485881228 0.7868454099060259 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 9039 0 3137
# This is start population distribution (male/female): 7649 4527
# This is iteration 0
# start population for this round:  12176
# old population after die out:  12176
# end population for this round:  21695
# Distribution for current iteration: 14304 3594 3797
# Population for current iteration (male/female): 12407 9288
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  21695
# old population after die out:  9519
# end population for this round:  26583
# Distribution for current iteration: 14551 10208 1824
# Population for current iteration (male/female): 13312 13271
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  26583
# old population after die out:  17064
# end population for this round:  37919
# Distribution for current iteration: 20753 14610 2556
# Population for current iteration (male/female): 18853 19066
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  37919
# old population after die out:  20855
# end population for this round:  50680
# Distribution for current iteration: 27809 19500 3371
# Population for current iteration (male/female): 25463 25217
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  50680
# old population after die out:  29825
# end population for this round:  69585
# Distribution for current iteration: 38093 26811 4681
# Population for current iteration (male/female): 35073 34512
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  38093 26811 4681
# Final Frequency after 5 iterations:  0.5474311992527126 0.3852985557232162 0.06727024502407128
# Final Distribution for a and A:  102997 36173
# Final Frequency for a and A:  0.7400804771143206 0.2599195228856794
# Final male and female population:  35073 34512
# ############################################################################
# THIS IS REPEAT: 4
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.2777473376817581 1525 4923 1 2 0.5179473247508664 0.901916318867385 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 1811 0 4637
# This is start population distribution (male/female): 1525 4923
# This is iteration 0
# start population for this round:  6448
# old population after die out:  3137
# end population for this round:  7034
# Distribution for current iteration: 1227 1583 4224
# Population for current iteration (male/female): 2688 4346
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  7034
# old population after die out:  1957
# end population for this round:  8157
# Distribution for current iteration: 669 3363 4125
# Population for current iteration (male/female): 4109 4048
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  8157
# old population after die out:  3110
# end population for this round:  8748
# Distribution for current iteration: 700 3686 4362
# Population for current iteration (male/female): 4344 4404
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  8748
# old population after die out:  2797
# end population for this round:  9615
# Distribution for current iteration: 787 4029 4799
# Population for current iteration (male/female): 4762 4853
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  9615
# old population after die out:  3362
# end population for this round:  11544
# Distribution for current iteration: 983 4760 5801
# Population for current iteration (male/female): 5702 5842
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  983 4760 5801
# Final Frequency after 5 iterations:  0.08515246015246015 0.4123354123354123 0.5025121275121275
# Final Distribution for a and A:  6726 16362
# Final Frequency for a and A:  0.29132016632016633 0.7086798336798337
# Final male and female population:  5702 5842
# ############################################################################
# THIS IS REPEAT: 5
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.28342550797641375 2529 1566 1 5 0.3766662304299534 0.9888269832763262 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 1161 0 2934
# This is start population distribution (male/female): 2529 1566
# This is iteration 0
# start population for this round:  4095
# old population after die out:  3280
# end population for this round:  6023
# Distribution for current iteration: 1149 1130 3744
# Population for current iteration (male/female): 3418 2605
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  6023
# old population after die out:  4634
# end population for this round:  8366
# Distribution for current iteration: 1159 2445 4762
# Population for current iteration (male/female): 4467 3899
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  8366
# old population after die out:  6250
# end population for this round:  10726
# Distribution for current iteration: 1232 3739 5755
# Population for current iteration (male/female): 5534 5192
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  10726
# old population after die out:  7745
# end population for this round:  12378
# Distribution for current iteration: 1214 4794 6370
# Population for current iteration (male/female): 6230 6148
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  12378
# old population after die out:  8449
# end population for this round:  18986
# Distribution for current iteration: 1569 7821 9596
# Population for current iteration (male/female): 9590 9396
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  1569 7821 9596
# Final Frequency after 5 iterations:  0.08263983988201833 0.4119351100811124 0.5054250500368692
# Final Distribution for a and A:  10959 27013
# Final Frequency for a and A:  0.28860739492257453 0.7113926050774255
# Final male and female population:  9590 9396
# ############################################################################
# THIS IS REPEAT: 6
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.23944648396449308 2664 9244 3 5 0.7364756913586781 0.9293258569109909 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 2826 0 9082
# This is start population distribution (male/female): 2664 9244
# This is iteration 0
# start population for this round:  11908
# old population after die out:  11908
# end population for this round:  22441
# Distribution for current iteration: 3449 3768 15224
# Population for current iteration (male/female): 7885 14556
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  22441
# old population after die out:  22441
# end population for this round:  39914
# Distribution for current iteration: 4409 10123 25382
# Population for current iteration (male/female): 16592 23322
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  39914
# old population after die out:  36033
# end population for this round:  71120
# Distribution for current iteration: 5471 22806 42843
# Population for current iteration (male/female): 33294 37826
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  71120
# old population after die out:  63553
# end population for this round:  117855
# Distribution for current iteration: 7305 41314 69236
# Population for current iteration (male/female): 57784 60071
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  117855
# old population after die out:  104476
# end population for this round:  193724
# Distribution for current iteration: 10781 70324 112619
# Population for current iteration (male/female): 97067 96657
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  10781 70324 112619
# Final Frequency after 5 iterations:  0.055651339018397306 0.36301129441886393 0.5813373665627387
# Final Distribution for a and A:  91886 295562
# Final Frequency for a and A:  0.23715698622782927 0.7628430137721707
# Final male and female population:  97067 96657
# ############################################################################
# THIS IS REPEAT: 7
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.4565582118984247 799 6354 3 4 0.17974066297857694 0.8966318069112617 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 3276 0 3877
# This is start population distribution (male/female): 799 6354
# This is iteration 0
# start population for this round:  7153
# old population after die out:  7153
# end population for this round:  12864
# Distribution for current iteration: 4458 2830 5576
# Population for current iteration (male/female): 3628 9236
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  12864
# old population after die out:  12864
# end population for this round:  23714
# Distribution for current iteration: 6729 8183 8802
# Population for current iteration (male/female): 9148 14566
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  23714
# old population after die out:  20191
# end population for this round:  32965
# Distribution for current iteration: 7755 14546 10664
# Population for current iteration (male/female): 15106 17859
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  32965
# old population after die out:  26514
# end population for this round:  55306
# Distribution for current iteration: 11381 27447 16478
# Population for current iteration (male/female): 27638 27668
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  55306
# old population after die out:  46903
# end population for this round:  81117
# Distribution for current iteration: 16744 40313 24060
# Population for current iteration (male/female): 40653 40464
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  16744 40313 24060
# Final Frequency after 5 iterations:  0.2064178902079712 0.4969735074028872 0.2966086023891416
# Final Distribution for a and A:  73801 88433
# Final Frequency for a and A:  0.4549046439094148 0.5450953560905852
# Final male and female population:  40653 40464
# ############################################################################
# THIS IS REPEAT: 8
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.285348239898928 6176 5913 1 3 0.3560286598884349 0.6777106714323097 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 3438 0 8651
# This is start population distribution (male/female): 6176 5913
# This is iteration 0
# start population for this round:  12089
# old population after die out:  8053
# end population for this round:  15722
# Distribution for current iteration: 2853 3150 9719
# Population for current iteration (male/female): 7890 7832
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  15722
# old population after die out:  9141
# end population for this round:  17886
# Distribution for current iteration: 2187 5642 10057
# Population for current iteration (male/female): 8951 8935
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  17886
# old population after die out:  8523
# end population for this round:  19861
# Distribution for current iteration: 1589 8017 10255
# Population for current iteration (male/female): 9893 9968
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  19861
# old population after die out:  10508
# end population for this round:  21424
# Distribution for current iteration: 1634 8682 11108
# Population for current iteration (male/female): 10618 10806
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  21424
# old population after die out:  11049
# end population for this round:  22400
# Distribution for current iteration: 1681 9030 11689
# Population for current iteration (male/female): 11170 11230
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  1681 9030 11689
# Final Frequency after 5 iterations:  0.07504464285714285 0.403125 0.5218303571428572
# Final Distribution for a and A:  12392 32408
# Final Frequency for a and A:  0.2766071428571429 0.7233928571428572
# Final male and female population:  11170 11230
# ############################################################################
# THIS IS REPEAT: 9
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.6122824621916445 4119 3377 4 5 0.17961799099714815 0.7892963738396894 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 4669 0 2827
# This is start population distribution (male/female): 4119 3377
# This is iteration 0
# start population for this round:  7496
# old population after die out:  7496
# end population for this round:  10891
# Distribution for current iteration: 6031 1577 3283
# Population for current iteration (male/female): 5831 5060
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  10891
# old population after die out:  10891
# end population for this round:  16848
# Distribution for current iteration: 8311 4379 4158
# Population for current iteration (male/female): 8782 8066
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  16848
# old population after die out:  16848
# end population for this round:  21409
# Distribution for current iteration: 10039 6571 4799
# Population for current iteration (male/female): 11067 10342
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  21409
# old population after die out:  17784
# end population for this round:  26471
# Distribution for current iteration: 11163 10617 4691
# Population for current iteration (male/female): 13452 13019
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  26471
# old population after die out:  20915
# end population for this round:  31125
# Distribution for current iteration: 11955 14646 4524
# Population for current iteration (male/female): 15589 15536
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  11955 14646 4524
# Final Frequency after 5 iterations:  0.3840963855421687 0.4705542168674699 0.14534939759036145
# Final Distribution for a and A:  38556 23694
# Final Frequency for a and A:  0.6193734939759036 0.38062650602409637
# Final male and female population:  15589 15536
# ############################################################################
# THIS IS REPEAT: 10
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.650425573993471 5339 5001 1 4 0.7917183010702998 0.9244943675493188 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 6718 0 3622
# This is start population distribution (male/female): 5339 5001
# This is iteration 0
# start population for this round:  10340
# old population after die out:  7737
# end population for this round:  17107
# Distribution for current iteration: 9048 4250 3809
# Population for current iteration (male/female): 8686 8421
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  17107
# old population after die out:  12188
# end population for this round:  25854
# Distribution for current iteration: 12280 9376 4198
# Population for current iteration (male/female): 12984 12870
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  25854
# old population after die out:  17466
# end population for this round:  37949
# Distribution for current iteration: 17092 15974 4883
# Population for current iteration (male/female): 18949 19000
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  37949
# old population after die out:  24590
# end population for this round:  56573
# Distribution for current iteration: 24706 25281 6586
# Population for current iteration (male/female): 28239 28334
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  56573
# old population after die out:  37779
# end population for this round:  83259
# Distribution for current iteration: 36348 37169 9742
# Population for current iteration (male/female): 41590 41669
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  36348 37169 9742
# Final Frequency after 5 iterations:  0.43656541635138546 0.4464262121812657 0.11700837146734888
# Final Distribution for a and A:  109865 56653
# Final Frequency for a and A:  0.6597785224420183 0.3402214775579817
# Final male and female population:  41590 41669
# ############################################################################
# THIS IS REPEAT: 11
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.6663700242552401 9031 4788 3 4 0.7234085065356418 0.8148196705559573 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 9183 0 4636
# This is start population distribution (male/female): 9031 4788
# This is iteration 0
# start population for this round:  13819
# old population after die out:  13819
# end population for this round:  24443
# Distribution for current iteration: 13924 4663 5856
# Population for current iteration (male/female): 14441 10002
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  24443
# old population after die out:  24443
# end population for this round:  44162
# Distribution for current iteration: 22630 13527 8005
# Population for current iteration (male/female): 24350 19812
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  44162
# old population after die out:  37272
# end population for this round:  70481
# Distribution for current iteration: 32939 28284 9258
# Population for current iteration (male/female): 36481 34000
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  70481
# old population after die out:  58255
# end population for this round:  113411
# Distribution for current iteration: 50464 50498 12449
# Population for current iteration (male/female): 56727 56684
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  113411
# old population after die out:  98167
# end population for this round:  182826
# Distribution for current iteration: 81173 81518 20135
# Population for current iteration (male/female): 91276 91550
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  81173 81518 20135
# Final Frequency after 5 iterations:  0.4439904608753678 0.4458775010118911 0.11013203811274108
# Final Distribution for a and A:  243864 121788
# Final Frequency for a and A:  0.6669292113813133 0.3330707886186866
# Final male and female population:  91276 91550
# ############################################################################
# THIS IS REPEAT: 12
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.5907608291855632 9319 1975 2 5 0.45343530492133577 0.7441029260951079 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 6630 0 4664
# This is start population distribution (male/female): 9319 1975
# This is iteration 0
# start population for this round:  11294
# old population after die out:  11294
# end population for this round:  17574
# Distribution for current iteration: 8794 3034 5746
# Population for current iteration (male/female): 12468 5106
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  17574
# old population after die out:  14727
# end population for this round:  24453
# Distribution for current iteration: 10567 7741 6145
# Population for current iteration (male/female): 14935 9518
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  24453
# old population after die out:  20073
# end population for this round:  37023
# Distribution for current iteration: 14320 15164 7539
# Population for current iteration (male/female): 20261 16762
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  37023
# old population after die out:  30088
# end population for this round:  48584
# Distribution for current iteration: 17805 22076 8703
# Population for current iteration (male/female): 25118 23466
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  48584
# old population after die out:  37582
# end population for this round:  71423
# Distribution for current iteration: 25271 34406 11746
# Population for current iteration (male/female): 35768 35655
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  25271 34406 11746
# Final Frequency after 5 iterations:  0.3538215980846506 0.48172157428279405 0.16445682763255534
# Final Distribution for a and A:  84948 57898
# Final Frequency for a and A:  0.5946823852260477 0.4053176147739524
# Final male and female population:  35768 35655
# ############################################################################
# THIS IS REPEAT: 13
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.9554585527484392 3879 4258 1 5 0.7445194112402563 0.9287765756626968 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 7795 0 342
# This is start population distribution (male/female): 3879 4258
# This is iteration 0
# start population for this round:  8137
# old population after die out:  6520
# end population for this round:  12699
# Distribution for current iteration: 11906 516 277
# Population for current iteration (male/female): 6283 6416
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  12699
# old population after die out:  9812
# end population for this round:  20195
# Distribution for current iteration: 18730 1232 233
# Population for current iteration (male/female): 10122 10073
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  20195
# old population after die out:  15236
# end population for this round:  31241
# Distribution for current iteration: 28811 2227 203
# Population for current iteration (male/female): 15536 15705
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  31241
# old population after die out:  23163
# end population for this round:  51625
# Distribution for current iteration: 47483 3969 173
# Population for current iteration (male/female): 25753 25872
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  51625
# old population after die out:  37816
# end population for this round:  84243
# Distribution for current iteration: 77400 6693 150
# Population for current iteration (male/female): 42161 42082
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  77400 6693 150
# Final Frequency after 5 iterations:  0.9187706990491792 0.07944873758057049 0.0017805633702503473
# Final Distribution for a and A:  161493 6993
# Final Frequency for a and A:  0.9584950678394644 0.04150493216053559
# Final male and female population:  42161 42082
# ############################################################################
# THIS IS REPEAT: 14
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.6750737328447579 6256 6814 4 4 0.21971387325220076 0.9519298915617138 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 8789 0 4281
# This is start population distribution (male/female): 6256 6814
# This is iteration 0
# start population for this round:  13070
# old population after die out:  13070
# end population for this round:  19622
# Distribution for current iteration: 11780 2862 4980
# Population for current iteration (male/female): 9559 10063
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  19622
# old population after die out:  19622
# end population for this round:  31982
# Distribution for current iteration: 17460 8231 6291
# Population for current iteration (male/female): 15677 16305
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  31982
# old population after die out:  31982
# end population for this round:  50454
# Distribution for current iteration: 25944 16251 8259
# Population for current iteration (male/female): 24807 25647
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  50454
# old population after die out:  37384
# end population for this round:  54949
# Distribution for current iteration: 25167 23988 5794
# Population for current iteration (male/female): 27262 27687
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  54949
# old population after die out:  48397
# end population for this round:  69134
# Distribution for current iteration: 31621 30274 7239
# Population for current iteration (male/female): 34399 34735
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  31621 30274 7239
# Final Frequency after 5 iterations:  0.4573871033066219 0.4379032024763503 0.1047096942170278
# Final Distribution for a and A:  93516 44752
# Final Frequency for a and A:  0.676338704544797 0.32366129545520295
# Final male and female population:  34399 34735
# ############################################################################
# THIS IS REPEAT: 15
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.18779187026283006 112 849 3 3 0.3927948450268517 0.42301841978501364 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 161 0 800
# This is start population distribution (male/female): 112 849
# This is iteration 0
# start population for this round:  961
# old population after die out:  961
# end population for this round:  1357
# Distribution for current iteration: 168 117 1072
# Population for current iteration (male/female): 322 1035
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  1357
# old population after die out:  1357
# end population for this round:  1924
# Distribution for current iteration: 186 280 1458
# Population for current iteration (male/female): 589 1335
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  1924
# old population after die out:  963
# end population for this round:  1719
# Distribution for current iteration: 46 484 1189
# Population for current iteration (male/female): 845 874
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  1719
# old population after die out:  1323
# end population for this round:  2021
# Distribution for current iteration: 66 565 1390
# Population for current iteration (male/female): 960 1061
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  2021
# old population after die out:  1454
# end population for this round:  2265
# Distribution for current iteration: 70 652 1543
# Population for current iteration (male/female): 1102 1163
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  70 652 1543
# Final Frequency after 5 iterations:  0.03090507726269316 0.2878587196467991 0.6812362030905077
# Final Distribution for a and A:  792 3738
# Final Frequency for a and A:  0.17483443708609273 0.8251655629139073
# Final male and female population:  1102 1163
# ############################################################################
# THIS IS REPEAT: 16
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.6670925375535397 1196 1067 2 2 0.5042129480665344 0.561482483079418 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 1495 0 768
# This is start population distribution (male/female): 1196 1067
# This is iteration 0
# start population for this round:  2263
# old population after die out:  2263
# end population for this round:  3443
# Distribution for current iteration: 2005 525 913
# Population for current iteration (male/female): 1766 1677
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  3443
# old population after die out:  1180
# end population for this round:  2998
# Distribution for current iteration: 1306 1339 353
# Population for current iteration (male/female): 1475 1523
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  2998
# old population after die out:  1818
# end population for this round:  3353
# Distribution for current iteration: 1485 1500 368
# Population for current iteration (male/female): 1702 1651
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  3353
# old population after die out:  1535
# end population for this round:  3329
# Distribution for current iteration: 1470 1514 345
# Population for current iteration (male/female): 1667 1662
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  3329
# old population after die out:  1794
# end population for this round:  3601
# Distribution for current iteration: 1593 1628 380
# Population for current iteration (male/female): 1761 1840
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  1593 1628 380
# Final Frequency after 5 iterations:  0.4423771174673702 0.4520966398222716 0.10552624271035824
# Final Distribution for a and A:  4814 2388
# Final Frequency for a and A:  0.668425437378506 0.33157456262149404
# Final male and female population:  1761 1840
# ############################################################################
# THIS IS REPEAT: 17
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.03110240303875811 3255 2644 1 2 0.1681658808583207 0.28469951489394363 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 181 0 5718
# This is start population distribution (male/female): 3255 2644
# This is iteration 0
# start population for this round:  5899
# old population after die out:  2958
# end population for this round:  4448
# Distribution for current iteration: 80 103 4265
# Population for current iteration (male/female): 2387 2061
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  4448
# old population after die out:  776
# end population for this round:  1988
# Distribution for current iteration: 3 124 1861
# Population for current iteration (male/female): 984 1004
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  1988
# old population after die out:  613
# end population for this round:  1106
# Distribution for current iteration: 0 64 1042
# Population for current iteration (male/female): 567 539
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  1106
# old population after die out:  251
# end population for this round:  484
# Distribution for current iteration: 0 25 459
# Population for current iteration (male/female): 255 229
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  484
# old population after die out:  109
# end population for this round:  232
# Distribution for current iteration: 0 17 215
# Population for current iteration (male/female): 125 107
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  0 17 215
# Final Frequency after 5 iterations:  0.0 0.07327586206896551 0.9267241379310345
# Final Distribution for a and A:  17 447
# Final Frequency for a and A:  0.036637931034482756 0.9633620689655172
# Final male and female population:  125 107
# ############################################################################
# THIS IS REPEAT: 18
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.8101695614270056 8926 7396 3 3 0.24836767554246983 0.44005070761848564 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 13167 0 3155
# ...
# Final Distribution for a and A:  41266 10084
# Final Frequency for a and A:  0.803622200584226 0.1963777994157741
# Final male and female population:  12837 12838
# ############################################################################
# THIS IS REPEAT: 19
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.761674736889171 7604 1538 2 4 0.46228609506454976 0.8405411302477861 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 6907 0 2235
# This is start population distribution (male/female): 7604 1538
# This is iteration 0
# start population for this round:  9142
# old population after die out:  9142
# end population for this round:  14150
# Distribution for current iteration: 9827 1784 2539
# Population for current iteration (male/female): 10158 3992
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  14150
# old population after die out:  11109
# end population for this round:  22394
# Distribution for current iteration: 14027 5962 2405
# Population for current iteration (male/female): 13153 9241
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  22394
# old population after die out:  17755
# end population for this round:  31830
# Distribution for current iteration: 18871 10602 2357
# Population for current iteration (male/female): 16797 15033
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  31830
# old population after die out:  23157
# end population for this round:  43554
# Distribution for current iteration: 25218 15920 2416
# Population for current iteration (male/female): 21594 21960
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  43554
# old population after die out:  33571
# end population for this round:  57679
# Distribution for current iteration: 33508 20996 3175
# Population for current iteration (male/female): 28837 28842
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  33508 20996 3175
# Final Frequency after 5 iterations:  0.5809393366736594 0.36401463270861145 0.055046030617729155
# Final Distribution for a and A:  88012 27346
# Final Frequency for a and A:  0.7629466530279652 0.2370533469720349
# Final male and female population:  28837 28842
# ############################################################################
# THIS IS REPEAT: 20
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.2746701609379568 8436 7122 3 3 0.15965362571894487 0.6949471845918548 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 4285 0 11273
# This is start population distribution (male/female): 8436 7122
# This is iteration 0
# start population for this round:  15558
# old population after die out:  15558
# end population for this round:  26090
# Distribution for current iteration: 5079 4228 16783
# Population for current iteration (male/female): 13624 12466
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  26090
# old population after die out:  26090
# end population for this round:  37140
# Distribution for current iteration: 5929 8552 22659
# Population for current iteration (male/female): 19173 17967
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  37140
# old population after die out:  21582
# end population for this round:  45104
# Distribution for current iteration: 3401 17752 23951
# Population for current iteration (male/female): 22590 22514
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  45104
# old population after die out:  34572
# end population for this round:  47425
# Distribution for current iteration: 3566 18632 25227
# Population for current iteration (male/female): 23781 23644
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  47425
# old population after die out:  36375
# end population for this round:  66493
# Distribution for current iteration: 4951 26181 35361
# Population for current iteration (male/female): 33302 33191
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  4951 26181 35361
# Final Frequency after 5 iterations:  0.07445896560540208 0.39374069450919646 0.5318003398854014
# Final Distribution for a and A:  36083 96903
# Final Frequency for a and A:  0.2713293128600003 0.7286706871399997
# Final male and female population:  33302 33191
# ############################################################################
# THIS IS REPEAT: 21
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.914825270613619 4131 8930 1 3 0.5197012757053983 0.6867057617870601 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 11954 0 1107
# This is start population distribution (male/female): 4131 8930
# This is iteration 0
# start population for this round:  13061
# old population after die out:  8678
# end population for this round:  17160
# Distribution for current iteration: 15023 1347 790
# Population for current iteration (male/female): 6946 10214
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  17160
# old population after die out:  9992
# end population for this round:  21234
# Distribution for current iteration: 18149 2600 485
# Population for current iteration (male/female): 9800 11434
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  21234
# old population after die out:  10327
# end population for this round:  23792
# Distribution for current iteration: 19907 3693 192
# Population for current iteration (male/female): 11884 11908
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  23792
# old population after die out:  12769
# end population for this round:  28912
# Distribution for current iteration: 24103 4581 228
# Population for current iteration (male/female): 14310 14602
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  28912
# old population after die out:  15088
# end population for this round:  30863
# Distribution for current iteration: 25745 4874 244
# Population for current iteration (male/female): 15313 15550
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  25745 4874 244
# Final Frequency after 5 iterations:  0.8341703658101934 0.1579237274406247 0.007905906749181868
# Final Distribution for a and A:  56364 5362
# Final Frequency for a and A:  0.9131322295305058 0.08686777046949422
# Final male and female population:  15313 15550
# ############################################################################
# THIS IS REPEAT: 22
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.4113522454009231 1191 7498 2 4 0.31628564457476904 0.8887642404299273 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 3529 0 5160
# This is start population distribution (male/female): 1191 7498
# This is iteration 0
# start population for this round:  8689
# old population after die out:  8689
# end population for this round:  15515
# Distribution for current iteration: 4614 3328 7573
# Population for current iteration (male/female): 4572 10943
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  15515
# old population after die out:  12696
# end population for this round:  26191
# Distribution for current iteration: 5658 9887 10646
# Population for current iteration (male/female): 10999 15192
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  26191
# old population after die out:  20993
# end population for this round:  31922
# Distribution for current iteration: 5889 14157 11876
# Population for current iteration (male/female): 14891 17031
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  31922
# old population after die out:  22232
# end population for this round:  39042
# Distribution for current iteration: 6470 18881 13691
# Population for current iteration (male/female): 19475 19567
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  39042
# old population after die out:  28545
# end population for this round:  50144
# Distribution for current iteration: 8397 24258 17489
# Population for current iteration (male/female): 25084 25060
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  8397 24258 17489
# Final Frequency after 5 iterations:  0.16745772176132737 0.48376675175494577 0.3487755264837269
# Final Distribution for a and A:  41052 59236
# Final Frequency for a and A:  0.4093410976388003 0.5906589023611998
# Final male and female population:  25084 25060
# ############################################################################
# THIS IS REPEAT: 23
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.7747331823389748 6640 3530 1 1 0.829686927268019 0.8664651021275441 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 7827 0 2343
# This is start population distribution (male/female): 6640 3530
# This is iteration 0
# start population for this round:  10170
# old population after die out:  0
# end population for this round:  8597
# Distribution for current iteration: 5186 2977 434
# Population for current iteration (male/female): 4269 4328
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  8597
# old population after die out:  0
# end population for this round:  7243
# Distribution for current iteration: 4336 2554 353
# Population for current iteration (male/female): 3600 3643
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  7243
# old population after die out:  0
# end population for this round:  6031
# Distribution for current iteration: 3598 2147 286
# Population for current iteration (male/female): 2992 3039
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  6031
# old population after die out:  0
# end population for this round:  5196
# Distribution for current iteration: 3100 1829 267
# Population for current iteration (male/female): 2551 2645
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  5196
# old population after die out:  0
# end population for this round:  4373
# Distribution for current iteration: 2624 1511 238
# Population for current iteration (male/female): 2206 2167
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  2624 1511 238
# Final Frequency after 5 iterations:  0.6000457351932312 0.345529384861651 0.05442487994511777
# Final Distribution for a and A:  6759 1987
# Final Frequency for a and A:  0.7728104276240567 0.22718957237594328
# Final male and female population:  2206 2167
# ############################################################################
# THIS IS REPEAT: 24
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# The parameters for this simulation(allele distribution, malePop, femalePop, minDieOut, maxDieOut, minCrossover, maxCrossover, Iteration number, isPlot):
#  0.279866414897193 7580 5235 3 4 0.3558867428491105 0.8272282147928351 5 False
# ---------------------------------------------------------------------------------------------
# This is start genetic distribution: 3597 0 9218
# This is start population distribution (male/female): 7580 5235
# This is iteration 0
# start population for this round:  12815
# old population after die out:  12815
# end population for this round:  20899
# Distribution for current iteration: 4204 3260 13435
# Population for current iteration (male/female): 11551 9348
# '============'================'=============='============='============='
# This is iteration 1
# start population for this round:  20899
# old population after die out:  20899
# end population for this round:  35147
# Distribution for current iteration: 5319 8947 20881
# Population for current iteration (male/female): 18674 16473
# '============'================'=============='============='============='
# This is iteration 2
# start population for this round:  35147
# old population after die out:  28845
# end population for this round:  56184
# Distribution for current iteration: 5597 20107 30480
# Population for current iteration (male/female): 28586 27598
# '============'================'=============='============='============='
# This is iteration 3
# start population for this round:  56184
# old population after die out:  45599
# end population for this round:  66504
# Distribution for current iteration: 5074 26958 34472
# Population for current iteration (male/female): 33156 33348
# '============'================'=============='============='============='
# This is iteration 4
# start population for this round:  66504
# old population after die out:  55295
# end population for this round:  84107
# Distribution for current iteration: 6493 34046 43568
# Population for current iteration (male/female): 42000 42107
# '============'================'=============='============='============='
# Final Distribution after 5 iterations:  6493 34046 43568
# Final Frequency after 5 iterations:  0.07719928186714542 0.40479389349281275 0.5180068246400419
# Final Distribution for a and A:  47032 121182
# Final Frequency for a and A:  0.27959622861355177 0.7204037713864482
# Final male and female population:  42000 42107
